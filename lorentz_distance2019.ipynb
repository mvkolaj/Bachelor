# %%
import torch
import pickle
import numpy as np
import pandas as pd
from lorentz import Lorentz

# load ENAO checkpoint and vocabulary
vocab = pickle.load(open("enoa_vocab.pkl", "rb"))
genre_to_idx = {genre: idx for idx, genre in enumerate(vocab)}
checkpoint = torch.load("ckpt/final_enoa_graph.ckpt", map_location="cpu")
embeddings = checkpoint["table.weight"].numpy()
print(f"ENAO vocabulary size: {len(vocab)} genres")

# load collaboration dataset
df = pd.read_csv("code/dataset/Original/global/global-genre_network-2019.csv", sep="\t")

# remove self loops and extract unique genres
df = df[df["source"] != df["target"]].copy()
collab_genres = set(df["source"].unique()) | set(df["target"].unique())
print(f"Unique genres in collaboration dataset: {len(collab_genres)}")

# extract and save embeddings for matching genres
matched = {}
unmatched = []
for genre in collab_genres:
    if genre in genre_to_idx:
        idx = genre_to_idx[genre] + 1
        matched[genre] = embeddings[idx]
    else:
        unmatched.append(genre)

print(f"Matched: {len(matched)} genres")
print(f"Unmatched (will be skipped): {len(unmatched)} genres")
if unmatched:
    print("Skipped genres:")
    for g in sorted(unmatched):
        print(f"  - {g}")

# save extracted embeddings for future use
pickle.dump(matched, open("collab_genre_embeddings.pkl", "wb"))
print("Saved extracted embeddings to collab_genre_embeddings.pkl")

# define Lorentz distance
def lorentz_scalar_product(u, v):
    return -u[0]*v[0] + np.dot(u[1:], v[1:])

def lorentz_distance(u, v):
    inner = lorentz_scalar_product(u, v)
    inner = min(inner, -1.0)
    return float(np.arccosh(-inner))

# compute distances for each collaboration pair
distances = []
skipped_rows = []
for _, row in df.iterrows():
    source = row["source"]
    target = row["target"]
    if source not in matched:
        skipped_rows.append((source, target, f"'{source}' not in ENAO embeddings"))
        distances.append(None)
        continue
    if target not in matched:
        skipped_rows.append((source, target, f"'{target}' not in ENAO embeddings"))
        distances.append(None)
        continue
    d = lorentz_distance(matched[source], matched[target])
    distances.append(d)

df["hyperbolic_distance"] = distances

# save results
df_clean = df.dropna(subset=["hyperbolic_distance"]).copy()
print(f"\nTotal collaboration pairs: {len(df)}")
print(f"Pairs skipped: {len(skipped_rows)}")
print(f"Pairs with distance computed: {len(df_clean)}")

if skipped_rows:
    print("\nSkipped rows log:")
    for source, target, reason in skipped_rows:
        print(f"  - {source} → {target}: {reason}")

df_clean.to_csv("collaborations_with_distances2019.csv", index=False)
print("\nSaved to collaborations_with_distances2019.csv")
print(df_clean[["source", "target", "weight", "avg_streams", "hyperbolic_distance"]].head(10))
# Out:
# collab_graph enoa_graph
# ENAO vocabulary size: 6280 genres
# Unique genres in collaboration dataset: 310
# Matched: 297 genres
# Unmatched (will be skipped): 13 genres
# Skipped genres:
#   - afro dancehall
#   - baile pop
#   - deep pop r&b
#   - dutch urban
#   - francoton
#   - k-hop
#   - latin
#   - lgbtq+ hip hop
#   - nc hip hop
#   - ninja
#   - regional mexican pop
#   - trap espanol
#   - vapor trap
# Saved extracted embeddings to collab_genre_embeddings.pkl
#
# Total collaboration pairs: 2854
# Pairs skipped: 278
# Pairs with distance computed: 2576
#
# Skipped rows log:
#   - latin → reggaeton: 'latin' not in ENAO embeddings
#   - latin → tropical: 'latin' not in ENAO embeddings
#   - latin → trap latino: 'latin' not in ENAO embeddings
#   - latin → reggaeton flow: 'latin' not in ENAO embeddings
#   - latin → latin hip hop: 'latin' not in ENAO embeddings
#   - latin → trap argentino: 'latin' not in ENAO embeddings
#   - latin → panamanian pop: 'latin' not in ENAO embeddings
#   - latin → latin pop: 'latin' not in ENAO embeddings
#   - colombian pop → latin: 'latin' not in ENAO embeddings
#   - latin → r&b en espanol: 'latin' not in ENAO embeddings
#   - latin → pop: 'latin' not in ENAO embeddings
#   - rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - nc hip hop → rap: 'nc hip hop' not in ENAO embeddings
#   - latin → puerto rican pop: 'latin' not in ENAO embeddings
#   - dance pop → latin: 'latin' not in ENAO embeddings
#   - underground hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - latin → rap latina: 'latin' not in ENAO embeddings
#   - latin → pop reggaeton: 'latin' not in ENAO embeddings
#   - latin → pop rap: 'latin' not in ENAO embeddings
#   - hip hop → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - baile pop → funk carioca: 'baile pop' not in ENAO embeddings
#   - nc hip hop → underground hip hop: 'nc hip hop' not in ENAO embeddings
#   - latin → post-teen pop: 'latin' not in ENAO embeddings
#   - argentine hip hop → latin: 'latin' not in ENAO embeddings
#   - latin → rap: 'latin' not in ENAO embeddings
#   - nc hip hop → trap: 'nc hip hop' not in ENAO embeddings
#   - edm → latin: 'latin' not in ENAO embeddings
#   - ninja → pop: 'ninja' not in ENAO embeddings
#   - latin → perreo: 'latin' not in ENAO embeddings
#   - pop rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - nc hip hop → pop rap: 'nc hip hop' not in ENAO embeddings
#   - trap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - atl hip hop → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - trap soul → vapor trap: 'vapor trap' not in ENAO embeddings
#   - baile pop → latin: 'baile pop' not in ENAO embeddings
#   - funk carioca → latin: 'latin' not in ENAO embeddings
#   - latin → tropical house: 'latin' not in ENAO embeddings
#   - latin → trap: 'latin' not in ENAO embeddings
#   - nc hip hop → southern hip hop: 'nc hip hop' not in ENAO embeddings
#   - dance pop → ninja: 'ninja' not in ENAO embeddings
#   - melodic rap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - atl trap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - nc hip hop → vapor trap: 'nc hip hop' not in ENAO embeddings
#   - electronic trap → latin: 'latin' not in ENAO embeddings
#   - funk das antigas → latin: 'latin' not in ENAO embeddings
#   - latin → pagode baiano: 'latin' not in ENAO embeddings
#   - baile pop → pop nacional: 'baile pop' not in ENAO embeddings
#   - melodic rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - bachata → latin: 'latin' not in ENAO embeddings
#   - latin → latin viral pop: 'latin' not in ENAO embeddings
#   - cali rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - baile pop → reggaeton: 'baile pop' not in ENAO embeddings
#   - ninja → post-teen pop: 'ninja' not in ENAO embeddings
#   - queens hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - sudanese pop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - atl hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - afro dancehall → pop: 'afro dancehall' not in ENAO embeddings
#   - electro house → latin: 'latin' not in ENAO embeddings
#   - miami hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - belgian edm → latin: 'latin' not in ENAO embeddings
#   - latin → latin arena pop: 'latin' not in ENAO embeddings
#   - latin → mexican pop: 'latin' not in ENAO embeddings
#   - baile pop → funk das antigas: 'baile pop' not in ENAO embeddings
#   - baile pop → pagode baiano: 'baile pop' not in ENAO embeddings
#   - electropop → latin: 'latin' not in ENAO embeddings
#   - colombian hip hop → latin: 'latin' not in ENAO embeddings
#   - conscious hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - country → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - emo rap → latin: 'latin' not in ENAO embeddings
#   - alternative r&b → vapor trap: 'vapor trap' not in ENAO embeddings
#   - baile pop → dance pop: 'baile pop' not in ENAO embeddings
#   - baile pop → pop: 'baile pop' not in ENAO embeddings
#   - latin → moombahton: 'latin' not in ENAO embeddings
#   - australian dance → ninja: 'ninja' not in ENAO embeddings
#   - australian pop → ninja: 'ninja' not in ENAO embeddings
#   - country road → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - dancehall → latin: 'latin' not in ENAO embeddings
#   - nc hip hop → queens hip hop: 'nc hip hop' not in ENAO embeddings
#   - nc hip hop → sudanese pop: 'nc hip hop' not in ENAO embeddings
#   - edm → ninja: 'ninja' not in ENAO embeddings
#   - ninja → tropical house: 'ninja' not in ENAO embeddings
#   - conscious hip hop → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - nc hip hop → trap soul: 'nc hip hop' not in ENAO embeddings
#   - meme rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - baile pop → electronic trap: 'baile pop' not in ENAO embeddings
#   - baile pop → latin pop: 'baile pop' not in ENAO embeddings
#   - latin → rap dominicano: 'latin' not in ENAO embeddings
#   - boy band → latin: 'latin' not in ENAO embeddings
#   - latin → pop rock: 'latin' not in ENAO embeddings
#   - baile pop → tropical: 'baile pop' not in ENAO embeddings
#   - belgian edm → dutch urban: 'dutch urban' not in ENAO embeddings
#   - cumbia → latin: 'latin' not in ENAO embeddings
#   - latin → latin alternative: 'latin' not in ENAO embeddings
#   - latin → latin rock: 'latin' not in ENAO embeddings
#   - latin → salsa choke: 'latin' not in ENAO embeddings
#   - latin → reggae fusion: 'latin' not in ENAO embeddings
#   - gangster rap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - afro dancehall → uk pop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → grime: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → uk hip hop: 'afro dancehall' not in ENAO embeddings
#   - electro house → ninja: 'ninja' not in ENAO embeddings
#   - moombahton → ninja: 'ninja' not in ENAO embeddings
#   - ninja → pop rap: 'ninja' not in ENAO embeddings
#   - afro dancehall → uk contemporary r&b: 'afro dancehall' not in ENAO embeddings
#   - dfw rap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - latin → viral pop: 'latin' not in ENAO embeddings
#   - southern hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - lgbtq+ hip hop → pop rap: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → rap: 'lgbtq+ hip hop' not in ENAO embeddings
#   - k-pop → latin: 'latin' not in ENAO embeddings
#   - latin → underground hip hop: 'latin' not in ENAO embeddings
#   - deep pop r&b → underground hip hop: 'deep pop r&b' not in ENAO embeddings
#   - hip hop → latin: 'latin' not in ENAO embeddings
#   - cali rap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - miami hip hop → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - afrofuturismo brasileiro → baile pop: 'baile pop' not in ENAO embeddings
#   - baile pop → bass trap: 'baile pop' not in ENAO embeddings
#   - k-pop → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - latin → melodic rap: 'latin' not in ENAO embeddings
#   - ninja → uk pop: 'ninja' not in ENAO embeddings
#   - chicago rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - baile pop → funk ostentacao: 'baile pop' not in ENAO embeddings
#   - baile pop → edm: 'baile pop' not in ENAO embeddings
#   - baile pop → pop rap: 'baile pop' not in ENAO embeddings
#   - bmore → latin: 'latin' not in ENAO embeddings
#   - latin → ninja: 'latin' not in ENAO embeddings
#   - ninja → reggaeton: 'ninja' not in ENAO embeddings
#   - hip pop → latin: 'latin' not in ENAO embeddings
#   - latin → queens hip hop: 'latin' not in ENAO embeddings
#   - latin → venezuelan hip hop: 'latin' not in ENAO embeddings
#   - basshall → latin: 'latin' not in ENAO embeddings
#   - dutch hip hop → latin: 'latin' not in ENAO embeddings
#   - dutch house → latin: 'latin' not in ENAO embeddings
#   - dutch urban → latin: 'dutch urban' not in ENAO embeddings
#   - dutch urban → reggaeton: 'dutch urban' not in ENAO embeddings
#   - dutch urban → tropical: 'dutch urban' not in ENAO embeddings
#   - dutch urban → edm: 'dutch urban' not in ENAO embeddings
#   - dutch urban → tropical house: 'dutch urban' not in ENAO embeddings
#   - belgian dance → latin: 'latin' not in ENAO embeddings
#   - big room → latin: 'latin' not in ENAO embeddings
#   - latin → progressive electro house: 'latin' not in ENAO embeddings
#   - latin → rock en espanol: 'latin' not in ENAO embeddings
#   - afro dancehall → latin: 'afro dancehall' not in ENAO embeddings
#   - afropop → latin: 'latin' not in ENAO embeddings
#   - ghanaian hip hop → latin: 'latin' not in ENAO embeddings
#   - latin → swedish dancehall: 'latin' not in ENAO embeddings
#   - afro dancehall → reggaeton: 'afro dancehall' not in ENAO embeddings
#   - electro latino → latin: 'latin' not in ENAO embeddings
#   - atl hip hop → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → trap: 'lgbtq+ hip hop' not in ENAO embeddings
#   - emo rap → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - emo → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → modern rock: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → pop punk: 'lgbtq+ hip hop' not in ENAO embeddings
#   - latin → miami hip hop: 'latin' not in ENAO embeddings
#   - latin → trap brasileiro: 'latin' not in ENAO embeddings
#   - dominican pop → latin: 'latin' not in ENAO embeddings
#   - contemporary country → ninja: 'ninja' not in ENAO embeddings
#   - country road → ninja: 'ninja' not in ENAO embeddings
#   - deep talent show → ninja: 'ninja' not in ENAO embeddings
#   - dance pop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - edm → vapor trap: 'vapor trap' not in ENAO embeddings
#   - electronic trap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - pop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - dirty south rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - lgbtq+ hip hop → pop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - deep pop r&b → latin: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → latin viral pop: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → rap latina: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → reggaeton: 'deep pop r&b' not in ENAO embeddings
#   - latin → video game music: 'latin' not in ENAO embeddings
#   - deep pop r&b → video game music: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → k-pop: 'deep pop r&b' not in ENAO embeddings
#   - canadian hip hop → latin: 'latin' not in ENAO embeddings
#   - canadian pop → latin: 'latin' not in ENAO embeddings
#   - latin → toronto rap: 'latin' not in ENAO embeddings
#   - alternative r&b → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - meme rap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - afrofuturismo brasileiro → latin: 'latin' not in ENAO embeddings
#   - bass trap → latin: 'latin' not in ENAO embeddings
#   - latin → pop nacional: 'latin' not in ENAO embeddings
#   - k-pop boy group → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - k-hop → k-pop: 'k-hop' not in ENAO embeddings
#   - k-hop → k-pop boy group: 'k-hop' not in ENAO embeddings
#   - country rap → k-hop: 'k-hop' not in ENAO embeddings
#   - k-hop → lgbtq+ hip hop: 'k-hop' not in ENAO embeddings
#   - k-hop → pop rap: 'k-hop' not in ENAO embeddings
#   - dance pop → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - nc hip hop → pop: 'nc hip hop' not in ENAO embeddings
#   - nc hip hop → post-teen pop: 'nc hip hop' not in ENAO embeddings
#   - latin → southern hip hop: 'latin' not in ENAO embeddings
#   - dfw rap → latin: 'latin' not in ENAO embeddings
#   - electropop → ninja: 'ninja' not in ENAO embeddings
#   - metropopolis → ninja: 'ninja' not in ENAO embeddings
#   - ninja → trap: 'ninja' not in ENAO embeddings
#   - chicago rap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - baile pop → post-teen pop: 'baile pop' not in ENAO embeddings
#   - baile pop → tropical house: 'baile pop' not in ENAO embeddings
#   - baile pop → uk pop: 'baile pop' not in ENAO embeddings
#   - baile pop → mexican pop: 'baile pop' not in ENAO embeddings
#   - latin → uk pop: 'latin' not in ENAO embeddings
#   - dembow → ninja: 'ninja' not in ENAO embeddings
#   - ninja → rap dominicano: 'ninja' not in ENAO embeddings
#   - ninja → reggaeton flow: 'ninja' not in ENAO embeddings
#   - ninja → tropical: 'ninja' not in ENAO embeddings
#   - dembow → latin: 'latin' not in ENAO embeddings
#   - house → ninja: 'ninja' not in ENAO embeddings
#   - colombian pop → regional mexican pop: 'regional mexican pop' not in ENAO embeddings
#   - latin → regional mexican pop: 'latin' not in ENAO embeddings
#   - latin pop → regional mexican pop: 'regional mexican pop' not in ENAO embeddings
#   - reggaeton → regional mexican pop: 'regional mexican pop' not in ENAO embeddings
#   - baile pop → r&b en espanol: 'baile pop' not in ENAO embeddings
#   - baile pop → trap latino: 'baile pop' not in ENAO embeddings
#   - baile pop → trap argentino: 'baile pop' not in ENAO embeddings
#   - baile pop → rap latina: 'baile pop' not in ENAO embeddings
#   - ninja → video game music: 'ninja' not in ENAO embeddings
#   - alternative r&b → ninja: 'ninja' not in ENAO embeddings
#   - german cloud rap → latin: 'latin' not in ENAO embeddings
#   - german hip hop → latin: 'latin' not in ENAO embeddings
#   - latin → schweizer rap: 'latin' not in ENAO embeddings
#   - latin → r&b: 'latin' not in ENAO embeddings
#   - dutch urban → latin hip hop: 'dutch urban' not in ENAO embeddings
#   - dance pop → dutch urban: 'dutch urban' not in ENAO embeddings
#   - dutch urban → pop: 'dutch urban' not in ENAO embeddings
#   - belgian dance → dutch urban: 'dutch urban' not in ENAO embeddings
#   - big room → dutch urban: 'dutch urban' not in ENAO embeddings
#   - dutch urban → electro house: 'dutch urban' not in ENAO embeddings
#   - dutch urban → progressive electro house: 'dutch urban' not in ENAO embeddings
#   - dutch urban → latin pop: 'dutch urban' not in ENAO embeddings
#   - dutch urban → rap latina: 'dutch urban' not in ENAO embeddings
#   - atl trap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - baile pop → forro: 'baile pop' not in ENAO embeddings
#   - baile pop → sertanejo pop: 'baile pop' not in ENAO embeddings
#   - k-hop → latin: 'k-hop' not in ENAO embeddings
#   - k-hop → latin viral pop: 'k-hop' not in ENAO embeddings
#   - k-hop → rap latina: 'k-hop' not in ENAO embeddings
#   - k-hop → reggaeton: 'k-hop' not in ENAO embeddings
#   - afro dancehall → trap latino: 'afro dancehall' not in ENAO embeddings
#   - dance pop → deep pop r&b: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → pop: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → post-teen pop: 'deep pop r&b' not in ENAO embeddings
#   - afro dancehall → dance pop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → post-teen pop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → r&b: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → melodic rap: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → pop rap: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → rap: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → trap: 'afro dancehall' not in ENAO embeddings
#   - atl trap → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - gangster rap → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → melodic rap: 'lgbtq+ hip hop' not in ENAO embeddings
#   - francoton → french hip hop: 'francoton' not in ENAO embeddings
#   - francoton → pop urbaine: 'francoton' not in ENAO embeddings
#   - latin → musica canaria: 'latin' not in ENAO embeddings
#   - canadian hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - canadian pop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - toronto rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - trap espanol → vapor twitch: 'trap espanol' not in ENAO embeddings
#   - latin pop → trap espanol: 'trap espanol' not in ENAO embeddings
#   - reggaeton chileno → trap espanol: 'trap espanol' not in ENAO embeddings
#   - trap chileno → trap espanol: 'trap espanol' not in ENAO embeddings
#   - grime → latin: 'latin' not in ENAO embeddings
#   - lgbtq+ hip hop → underground hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → miami hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - baile pop → dancehall: 'baile pop' not in ENAO embeddings
#   - baile pop → latin hip hop: 'baile pop' not in ENAO embeddings
#   - baile pop → pop reggaeton: 'baile pop' not in ENAO embeddings
#   - baile pop → reggaeton flow: 'baile pop' not in ENAO embeddings
#   - latin → zimdancehall: 'latin' not in ENAO embeddings
#   - baile pop → brega funk: 'baile pop' not in ENAO embeddings
#   - boy band → ninja: 'ninja' not in ENAO embeddings
#   - ninja → pop rock: 'ninja' not in ENAO embeddings
#   - escape room → vapor trap: 'vapor trap' not in ENAO embeddings
#   - country rap → nc hip hop: 'nc hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → nc hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - latin → pop argentino: 'latin' not in ENAO embeddings
#   - chicago rap → latin: 'latin' not in ENAO embeddings
#
# Saved to collaborations_with_distances.csv
#        source          target  weight   avg_streams  hyperbolic_distance
# 2     pop rap             rap     222  5.385630e+07             0.151346
# 3         rap            trap     218  6.656220e+07             1.589537
# 4     hip hop             rap     203  5.405006e+07             0.936339
# 10  dance pop             pop     183  8.603006e+07             3.045446
# 12  reggaeton        tropical     166  9.791366e+07             5.400738
# 13  reggaeton     trap latino     165  1.179733e+08             0.310082
# 14  reggaeton  reggaeton flow     159  1.157272e+08             0.566698
# 15        pop   post-teen pop     157  9.704404e+07             0.080033
# 17    pop rap            trap     130  5.578200e+07             1.734451
# 18        pop         pop rap     122  6.606755e+07             6.244612
