# %%
import torch
import pickle
import numpy as np
import pandas as pd
from lorentz import Lorentz

# load ENAO checkpoint and vocabulary
vocab = pickle.load(open("enoa_vocab.pkl", "rb"))
genre_to_idx = {genre: idx for idx, genre in enumerate(vocab)}
checkpoint = torch.load("ckpt/final_enoa_graph.ckpt", map_location="cpu")
embeddings = checkpoint["table.weight"].numpy()
print(f"ENAO vocabulary size: {len(vocab)} genres")

# load collaboration dataset
df = pd.read_csv("code/dataset/Original/global/global-genre_network-2017.csv", sep="\t")

# remove self loops and extract unique genres
df = df[df["source"] != df["target"]].copy()
collab_genres = set(df["source"].unique()) | set(df["target"].unique())
print(f"Unique genres in collaboration dataset: {len(collab_genres)}")

# extract and save embeddings for matching genres
matched = {}
unmatched = []
for genre in collab_genres:
    if genre in genre_to_idx:
        idx = genre_to_idx[genre] + 1
        matched[genre] = embeddings[idx]
    else:
        unmatched.append(genre)

print(f"Matched: {len(matched)} genres")
print(f"Unmatched (will be skipped): {len(unmatched)} genres")
if unmatched:
    print("Skipped genres:")
    for g in sorted(unmatched):
        print(f"  - {g}")

# save extracted embeddings for future use
pickle.dump(matched, open("collab_genre_embeddings.pkl", "wb"))
print("Saved extracted embeddings to collab_genre_embeddings.pkl")

# define Lorentz distance
def lorentz_scalar_product(u, v):
    return -u[0]*v[0] + np.dot(u[1:], v[1:])

def lorentz_distance(u, v):
    inner = lorentz_scalar_product(u, v)
    inner = min(inner, -1.0)
    return float(np.arccosh(-inner))

# compute distances for each collaboration pair
distances = []
skipped_rows = []
for _, row in df.iterrows():
    source = row["source"]
    target = row["target"]
    if source not in matched:
        skipped_rows.append((source, target, f"'{source}' not in ENAO embeddings"))
        distances.append(None)
        continue
    if target not in matched:
        skipped_rows.append((source, target, f"'{target}' not in ENAO embeddings"))
        distances.append(None)
        continue
    d = lorentz_distance(matched[source], matched[target])
    distances.append(d)

df["hyperbolic_distance"] = distances

# save results
df_clean = df.dropna(subset=["hyperbolic_distance"]).copy()
print(f"\nTotal collaboration pairs: {len(df)}")
print(f"Pairs skipped: {len(skipped_rows)}")
print(f"Pairs with distance computed: {len(df_clean)}")

if skipped_rows:
    print("\nSkipped rows log:")
    for source, target, reason in skipped_rows:
        print(f"  - {source} → {target}: {reason}")

df_clean.to_csv("collaborations_with_distances2017.csv", index=False)
print("\nSaved to collaborations_with_distances2017.csv")
print(df_clean[["source", "target", "weight", "avg_streams", "hyperbolic_distance"]].head(10))
# Out:
# collab_graph enoa_graph
# ENAO vocabulary size: 6280 genres
# Unique genres in collaboration dataset: 258
# Matched: 248 genres
# Unmatched (will be skipped): 10 genres
# Skipped genres:
#   - afro dancehall
#   - baile pop
#   - deep pop r&b
#   - francoton
#   - indie cafe pop
#   - kwaito house
#   - latin
#   - lgbtq+ hip hop
#   - ninja
#   - vapor trap
# Saved extracted embeddings to collab_genre_embeddings.pkl
#
# Total collaboration pairs: 2588
# Pairs skipped: 156
# Pairs with distance computed: 2432
#
# Skipped rows log:
#   - latin → reggaeton: 'latin' not in ENAO embeddings
#   - latin → tropical: 'latin' not in ENAO embeddings
#   - latin → latin hip hop: 'latin' not in ENAO embeddings
#   - latin → reggaeton flow: 'latin' not in ENAO embeddings
#   - latin → trap latino: 'latin' not in ENAO embeddings
#   - latin → latin pop: 'latin' not in ENAO embeddings
#   - latin → pop: 'latin' not in ENAO embeddings
#   - dance pop → latin: 'latin' not in ENAO embeddings
#   - latin → puerto rican pop: 'latin' not in ENAO embeddings
#   - colombian pop → latin: 'latin' not in ENAO embeddings
#   - baile pop → funk carioca: 'baile pop' not in ENAO embeddings
#   - latin → post-teen pop: 'latin' not in ENAO embeddings
#   - latin → pop rap: 'latin' not in ENAO embeddings
#   - latin → perreo: 'latin' not in ENAO embeddings
#   - cubaton → latin: 'latin' not in ENAO embeddings
#   - lgbtq+ hip hop → rap: 'lgbtq+ hip hop' not in ENAO embeddings
#   - latin → mexican pop: 'latin' not in ENAO embeddings
#   - bachata → latin: 'latin' not in ENAO embeddings
#   - latin → latin arena pop: 'latin' not in ENAO embeddings
#   - latin → rap latina: 'latin' not in ENAO embeddings
#   - hip hop → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - latin → latin viral pop: 'latin' not in ENAO embeddings
#   - baile pop → dance pop: 'baile pop' not in ENAO embeddings
#   - baile pop → pop: 'baile pop' not in ENAO embeddings
#   - funk carioca → latin: 'latin' not in ENAO embeddings
#   - deep pop r&b → edm: 'deep pop r&b' not in ENAO embeddings
#   - champeta → latin: 'latin' not in ENAO embeddings
#   - latin → vallenato: 'latin' not in ENAO embeddings
#   - baile pop → funk das antigas: 'baile pop' not in ENAO embeddings
#   - baile pop → pagode baiano: 'baile pop' not in ENAO embeddings
#   - baile pop → pop nacional: 'baile pop' not in ENAO embeddings
#   - baile pop → detroit hip hop: 'baile pop' not in ENAO embeddings
#   - dancehall → latin: 'latin' not in ENAO embeddings
#   - baile pop → edm: 'baile pop' not in ENAO embeddings
#   - baile pop → electro house: 'baile pop' not in ENAO embeddings
#   - baile pop → tropical house: 'baile pop' not in ENAO embeddings
#   - baile pop → pop rap: 'baile pop' not in ENAO embeddings
#   - latin → rap: 'latin' not in ENAO embeddings
#   - latin → southern hip hop: 'latin' not in ENAO embeddings
#   - latin → trap: 'latin' not in ENAO embeddings
#   - latin → spanish pop: 'latin' not in ENAO embeddings
#   - francoton → latin: 'francoton' not in ENAO embeddings
#   - francoton → reggaeton: 'francoton' not in ENAO embeddings
#   - girl group → latin: 'latin' not in ENAO embeddings
#   - latin → talent show: 'latin' not in ENAO embeddings
#   - latin → uk pop: 'latin' not in ENAO embeddings
#   - dance pop → deep pop r&b: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → pop: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → tropical house: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → uk dance: 'deep pop r&b' not in ENAO embeddings
#   - dance pop → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - edm → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - electro house → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - house → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → pop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → progressive house: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → tropical house: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → uk dance: 'lgbtq+ hip hop' not in ENAO embeddings
#   - atl hip hop → lgbtq+ hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → pop rap: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → southern hip hop: 'lgbtq+ hip hop' not in ENAO embeddings
#   - lgbtq+ hip hop → trap: 'lgbtq+ hip hop' not in ENAO embeddings
#   - francoton → pop: 'francoton' not in ENAO embeddings
#   - edm → indie cafe pop: 'indie cafe pop' not in ENAO embeddings
#   - indie cafe pop → pop: 'indie cafe pop' not in ENAO embeddings
#   - indie cafe pop → tropical house: 'indie cafe pop' not in ENAO embeddings
#   - afrofuturismo brasileiro → baile pop: 'baile pop' not in ENAO embeddings
#   - baile pop → bass trap: 'baile pop' not in ENAO embeddings
#   - baile pop → electronic trap: 'baile pop' not in ENAO embeddings
#   - latin → miami hip hop: 'latin' not in ENAO embeddings
#   - deep pop r&b → hip hop: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → pop rap: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → rap: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → southern hip hop: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → trap: 'deep pop r&b' not in ENAO embeddings
#   - latin → reggae fusion: 'latin' not in ENAO embeddings
#   - baile pop → latin: 'baile pop' not in ENAO embeddings
#   - baile pop → reggaeton: 'baile pop' not in ENAO embeddings
#   - funk das antigas → latin: 'latin' not in ENAO embeddings
#   - latin → pop reggaeton: 'latin' not in ENAO embeddings
#   - electro latino → latin: 'latin' not in ENAO embeddings
#   - baile pop → moombahton: 'baile pop' not in ENAO embeddings
#   - atl hip hop → latin: 'latin' not in ENAO embeddings
#   - latin → uk dancehall: 'latin' not in ENAO embeddings
#   - latin → uk hip hop: 'latin' not in ENAO embeddings
#   - afro dancehall → pop rap: 'afro dancehall' not in ENAO embeddings
#   - canadian pop → latin: 'latin' not in ENAO embeddings
#   - latin → r&b: 'latin' not in ENAO embeddings
#   - dance pop → francoton: 'francoton' not in ENAO embeddings
#   - francoton → post-teen pop: 'francoton' not in ENAO embeddings
#   - francoton → r&b: 'francoton' not in ENAO embeddings
#   - latin → soca: 'latin' not in ENAO embeddings
#   - baile pop → big room: 'baile pop' not in ENAO embeddings
#   - baile pop → progressive electro house: 'baile pop' not in ENAO embeddings
#   - baile pop → progressive house: 'baile pop' not in ENAO embeddings
#   - australian hip hop → baile pop: 'baile pop' not in ENAO embeddings
#   - baile pop → hip pop: 'baile pop' not in ENAO embeddings
#   - baile pop → post-teen pop: 'baile pop' not in ENAO embeddings
#   - latin → urban contemporary: 'latin' not in ENAO embeddings
#   - escape room → latin: 'latin' not in ENAO embeddings
#   - latin → trap queen: 'latin' not in ENAO embeddings
#   - deep pop r&b → detroit hip hop: 'deep pop r&b' not in ENAO embeddings
#   - big room → indie cafe pop: 'indie cafe pop' not in ENAO embeddings
#   - dance pop → indie cafe pop: 'indie cafe pop' not in ENAO embeddings
#   - deep tropical house → indie cafe pop: 'indie cafe pop' not in ENAO embeddings
#   - electro house → indie cafe pop: 'indie cafe pop' not in ENAO embeddings
#   - electropop → indie cafe pop: 'indie cafe pop' not in ENAO embeddings
#   - house → indie cafe pop: 'indie cafe pop' not in ENAO embeddings
#   - indie cafe pop → pop edm: 'indie cafe pop' not in ENAO embeddings
#   - hip hop → latin: 'latin' not in ENAO embeddings
#   - latin → pagode baiano: 'latin' not in ENAO embeddings
#   - electropop → francoton: 'francoton' not in ENAO embeddings
#   - francoton → tropical house: 'francoton' not in ENAO embeddings
#   - latin → modern reggae: 'latin' not in ENAO embeddings
#   - latin → reggae: 'latin' not in ENAO embeddings
#   - latin → roots reggae: 'latin' not in ENAO embeddings
#   - canadian hip hop → kwaito house: 'kwaito house' not in ENAO embeddings
#   - canadian pop → kwaito house: 'kwaito house' not in ENAO embeddings
#   - hip hop → kwaito house: 'kwaito house' not in ENAO embeddings
#   - kwaito house → pop rap: 'kwaito house' not in ENAO embeddings
#   - kwaito house → rap: 'kwaito house' not in ENAO embeddings
#   - kwaito house → toronto rap: 'kwaito house' not in ENAO embeddings
#   - kwaito house → pop: 'kwaito house' not in ENAO embeddings
#   - kwaito house → uk contemporary r&b: 'kwaito house' not in ENAO embeddings
#   - east coast hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - pop rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - rap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - southern hip hop → vapor trap: 'vapor trap' not in ENAO embeddings
#   - trap → vapor trap: 'vapor trap' not in ENAO embeddings
#   - latin → panamanian pop: 'latin' not in ENAO embeddings
#   - boy band → latin: 'latin' not in ENAO embeddings
#   - brostep → deep pop r&b: 'deep pop r&b' not in ENAO embeddings
#   - complextro → deep pop r&b: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → electro: 'deep pop r&b' not in ENAO embeddings
#   - deep pop r&b → electro house: 'deep pop r&b' not in ENAO embeddings
#   - dance pop → ninja: 'ninja' not in ENAO embeddings
#   - danish pop → ninja: 'ninja' not in ENAO embeddings
#   - electropop → ninja: 'ninja' not in ENAO embeddings
#   - indie pop → ninja: 'ninja' not in ENAO embeddings
#   - indie poptimism → ninja: 'ninja' not in ENAO embeddings
#   - ninja → pop: 'ninja' not in ENAO embeddings
#   - ninja → tropical house: 'ninja' not in ENAO embeddings
#   - afro dancehall → dance pop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → edm: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → electro house: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → moombahton: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → pop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → tropical house: 'afro dancehall' not in ENAO embeddings
#   - dominican pop → latin: 'latin' not in ENAO embeddings
#   - afro dancehall → canadian hip hop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → canadian pop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → hip hop: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → rap: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → toronto rap: 'afro dancehall' not in ENAO embeddings
#   - afro dancehall → uk funky: 'afro dancehall' not in ENAO embeddings
#
# Saved to collaborations_with_distances2017.csv
#        source            target  weight   avg_streams  hyperbolic_distance
# 0     pop rap               rap     326  5.530821e+07             0.151346
# 1         rap              trap     268  6.606110e+07             1.589537
# 2     hip hop               rap     250  5.886272e+07             0.936339
# 3     pop rap              trap     236  6.379875e+07             1.734451
# 4   dance pop               pop     223  1.315518e+08             3.045446
# 5         pop           pop rap     216  8.979845e+07             6.244612
# 6     hip hop           pop rap     214  6.028990e+07             0.785089
# 7         pop               rap     207  6.965008e+07             6.182096
# 9     hip hop              trap     178  5.505757e+07             2.502273
# 11        rap  southern hip hop     165  4.841368e+07             0.024079
